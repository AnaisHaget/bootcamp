# %% [markdown]
# # Exercise 5.5

# %%
import numpy as np
import pandas as pd
import scipy.stats

import bokeh.io
import bokeh.layouts
import bokeh.models
import bokeh.plotting

notebook_url = 'localhost:8888' # Check browser, need to specify for output dashboard
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
def heatmap(x, y, z):
    pass

# %%
# !head -20 data/96_well.csv
df = pd.read_csv('data/96_well.csv', comment='#') 
df
# Out:
# row,column,absorbance,experiment
# A,1,1.74,exp
# B,1,1.88,exp
# C,1,1.84,exp
# D,1,1.85,exp
# E,1,1.84,exp
# F,1,1.79,exp
# G,1,1.78,exp
# H,1,1.57,exp
# A,2,1.71,exp
# B,2,1.91,exp
# C,2,1.85,exp
# D,2,1.91,exp
# E,2,1.84,exp
# F,2,1.86,exp
# G,2,1.71,exp
# H,2,1.65,exp
# A,3,1.80,exp
# B,3,1.98,exp
# C,3,1.93,exp
#    row  column  absorbance experiment
# 0    A       1        1.74        exp
# 1    B       1        1.88        exp
# 2    C       1        1.84        exp
# 3    D       1        1.85        exp
# 4    E       1        1.84        exp
# ..  ..     ...         ...        ...
# 91   D      12        1.68        exp
# 92   E      12        0.88    sterile
# 93   F      12        0.98   negative
# 94   G      12        0.96   negative
# 95   H      12        1.00   negative
#
# [96 rows x 4 columns]
